# %%
import numpy as np 
#np hum use kiye ye numpy ko short krne ke liye nickname alias diye

# %%
a=np.array([10,30,20,40])#np.array  ye python list ko array me convert kr rha hai np jo numpy hai isliye humm likhte hai
a
# Out:
# array([10, 30, 20, 40])

# %%
print(a[0])
# Out:
# 10

# %%
print(a[0:1])
#dono me 10 hi output aya bt difference hai index me single value retrun krta 
#or sliceing me type object ke sath me important line haii ye
# Out:
# [10]

# %%
print(a[0:2])
# Out:
# [10 30]

# %%
a=np.array([100,200,300,400])
b=a*10
b
# Out:
# array([1000, 2000, 3000, 4000])

# %%
print(b[1])
# Out:
# 2000

# %%
print(b[1:3])
# Out:
# [2000 3000]
