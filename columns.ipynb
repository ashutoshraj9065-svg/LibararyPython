# %%
import pandas as pd 
import numpy as np

# %%
data={"Name":["Ashu","banty","badal"],
      "Age":[22,24,26],
      "marks":[56,65,72]}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age  marks
# 0   Ashu   22     56
# 1  banty   24     65
# 2  badal   26     72

# %%
df["Age"]
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
df[["Age","Name"]]
type(df[["Age","Name"]])
# Out:
# pandas.core.frame.DataFrame
