# %%
import pandas as pd 
data={"name":["ashu","rohan","badal","monu"],
      "marks":[70,62,82,55],
      "age":[22,32,20,19]
      }
df=pd.DataFrame(data)
print(df.shape[0])
print(df.shape[1])
print(df.shape)
# Out:
# 4
# 3
# (4, 3)
