# %%
import pandas as pd 
data={"name":["ashu","rohan","badal","monu"],
      "marks":[70,62,82,55],
      "age":[22,32,20,19]
      }
df=pd.DataFrame(data)
print(df.shape[0])
print(df.shape[1])
print(df.shape)
print(df.columns[0])
# Out:
# 4
# 3
# (4, 3)
# name

# %%
print(df.head(2))
print(df.info)
# Out:
#     name  marks  age
# 0   ashu     70   22
# 1  rohan     62   32
# <bound method DataFrame.info of     name  marks  age
# 0   ashu     70   22
# 1  rohan     62   32
# 2  badal     82   20
# 3   monu     55   19>
