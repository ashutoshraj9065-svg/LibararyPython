# %%
import numpy as np

# %%
arr=np.array([10,20,30,40,50,60])
arr1=arr.reshape(2,3)
arr1
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
arr1.flatten()
# Out:
# array([10, 20, 30, 40, 50, 60])
